# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopikagovindan/assesment/blob/main/filmnw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing all packages required
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from IPython.display import clear_output

# %%
#creating empty lists inorder to append
name=[]
yr=[]
certif=[]
stars=[]
duration=[]
genre=[]
votes=[]
metascore=[]

#base url of the site
base_url='https://www.imdb.com/search/title/?release_date=2021-01-01,2021-12-31&sort=num_votes,desc&start='

#scraping 550 movie info 
for i in range(1,502,50):
    
    time.sleep(3)
    print(f'Scrapping for {i}')
    clear_output(wait=True)
    
    url=base_url+str(i)+'&ref_=adv_nxt'
    req=requests.get(url)
    soup=BeautifulSoup(req.text,'html')
# Out:
# Scrapping for 501

# %%
#movie_name
nam=soup.findAll('h3',attrs={'class':'lister-item-header'})
for j in nam:
  name.append(j.a.text)

# %%
#year_of_release
yer=soup.findAll('h3',{'class':'lister-item-header'})
for k in yer:
  yr.append((k.find('span',attrs={'class':'lister-item-year text-muted unbold'}).text.replace('(','').replace(')','')))

# %%
#duration
full=soup.findAll('div',{'class':'lister-item mode-advanced'})
for l in full:
  t=l.find('span',{'class':'runtime'})
  if t is not None:
    duration.append(t.text)
  else:
    duration.append("Not available")

# %%
#certification
c=soup.findAll('div',{'class':'lister-item mode-advanced'})
for m in c:
  certif.append(m.find('p',{'class':'text-muted'}).span.text)

# %%
 #star
star=soup.findAll('div',attrs={'class':'ratings-bar'})
for n in star:
  stars.append(n.strong.text)

# %%
#metascore
mta=soup.findAll('div',{'class':'ratings-bar'})
for o in mta:
  a=o.find('span',attrs={'class':'metascore'})
  if a is not None:
    metascore.append(a.text.strip())
  else:
    metascore.append('Not available')

# %%
#genre
genr=soup.findAll('span',attrs={'class':'genre'})
for p in genr:
  genre.append(p.text.strip())

# %%
#votes
v=soup.findAll('p',{'class':'sort-num_votes-visible'})
for q in v:
  votes.append(q.find('span',{'name':'nv'}).text)

# %%
data=pd.DataFrame({'Movie_name':name,
                  'Year_of_release':yr,
                  'Certification':certif,
                  'Duration':duration,
                  'imdb_rating':stars,
                  'Genre':genre,
                  'Votes':votes,
                  'Metascore':metascore})

# %%
data
# Out:
#                         Movie_name Year_of_release  ...  Votes      Metascore
# 0                       Young Rock          2021–   ...  1,817  Not available
# 1                         The Frog       2020–2021  ...  1,813  Not available
# 2                         The Frog       2020–2021  ...  1,813  Not available
# 3                            Mouse          2021–   ...  1,807  Not available
# 4                   Jujutsu Kaisen          2020–   ...  1,803  Not available
# 5              The Pursuit of Love          2021–   ...  1,787  Not available
# 6                   Resident Alien          2021–   ...  1,783  Not available
# 7                         The Soul            2021  ...  1,780  Not available
# 8                  The Great North          2021–   ...  1,765  Not available
# 9                          Dracula          2021–   ...  1,738  Not available
# 10                        Dystopia          2021–   ...  1,736  Not available
# 11                          iCarly          2021–   ...  1,735  Not available
# 12             Wonder Egg Priority          2021–   ...  1,735  Not available
# 13  LOL: Last One Laughing Germany          2021–   ...  1,725  Not available
# 14      Exterminate All the Brutes            2021  ...  1,722  Not available
# 15                       One Piece          1999–   ...  1,714  Not available
# 16                     Indori Ishq          2021–   ...  1,711  Not available
# 17                    Zombie Reddy            2021  ...  1,713  Not available
# 18                       Too Close            2021  ...  1,710  Not available
# 19                        The Frog       2020–2021  ...  1,709  Not available
# 20                A Perfect Planet            2021  ...  1,709  Not available
# 21                        The Pact          2021–   ...  1,704  Not available
# 22                          Domina          2021–   ...  1,697  Not available
# 23                   Lisey's Story            2021  ...  1,697  Not available
# 24               Superman and Lois          2021–   ...  1,696  Not available
# 25           Fear the Walking Dead          2015–   ...  1,694  Not available
# 26                            Dude          2021–   ...  1,692  Not available
# 27                           Doors            2021  ...  1,685  Not available
# 28                           Twist            2021  ...  1,679  Not available
# 29                  Tenkuu Shinpan          2021–   ...  1,677  Not available
# 30                          Plan B         II 2021  ...  1,677             74
# 31             The Handmaid's Tale          2017–   ...  1,675  Not available
# 32                  Jujutsu Kaisen          2020–   ...  1,674  Not available
# 33           Fear the Walking Dead          2015–   ...  1,674  Not available
# 34                      Homunculus            2021  ...  1,663  Not available
# 35             The Handmaid's Tale          2017–   ...  1,659  Not available
# 36                       The Flash          2014–   ...  1,655  Not available
# 37             The Handmaid's Tale          2017–   ...  1,653  Not available
# 38                     The Upshaws          2021–   ...  1,648  Not available
# 39                       One Piece          1999–   ...  1,644  Not available
# 40                 One Small Story            2021  ...  1,641  Not available
# 41                       The Flash          2014–   ...  1,631  Not available
# 42                          Cypher          2021–   ...  1,619  Not available
# 43                Douluo Continent          2021–   ...  1,617  Not available
# 44                        Leonardo          2021–   ...  1,613  Not available
# 45            When Calls the Heart          2014–   ...  1,608  Not available
# 46             The Handmaid's Tale          2017–   ...  1,608  Not available
# 47                   Gaali Sampath            2021  ...  1,605  Not available
# 48           Nenjam Marappathillai            2021  ...  1,603  Not available
# 49             The Handmaid's Tale          2017–   ...  1,597  Not available
#
# [50 rows x 8 columns]
